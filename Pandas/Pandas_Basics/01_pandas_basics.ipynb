# %%
import pandas as pd

# %%
# Using pandas read_csv method
df = pd.read_csv('./data/states.csv')

# %%
# Using head() method gets you the first five rows sample view
first_5 = df.head()
first_5
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
# Using tail() method gets you the last five rows
last_5 = df.tail()
last_5
# Out:
#             State Abbrev Code
# 46       Virginia    Va.   VA
# 47     Washington  Wash.   WA
# 48  West Virginia  W.Va.   WV
# 49      Wisconsin   Wis.   WI
# 50        Wyoming   Wyo.   WY

# %%
# We can also control how many rows can be displayed via head
df.head(8)
# Out:
#          State  Abbrev Code
# 0      Alabama    Ala.   AL
# 1       Alaska  Alaska   AK
# 2      Arizona   Ariz.   AZ
# 3     Arkansas    Ark.   AR
# 4   California  Calif.   CA
# 5     Colorado   Colo.   CO
# 6  Connecticut   Conn.   CT
# 7     Delaware    Del.   DE

# %%
# We can also control how many rows can be displayed via tail
df.tail(8)
# Out:
#             State Abbrev Code
# 43          Texas   Tex.   TX
# 44           Utah   Utah   UT
# 45        Vermont    Vt.   VT
# 46       Virginia    Va.   VA
# 47     Washington  Wash.   WA
# 48  West Virginia  W.Va.   WV
# 49      Wisconsin   Wis.   WI
# 50        Wyoming   Wyo.   WY

# %%
# To check the data TYPE we use TYPE
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# To get he complete column names
df.columns
# Out:
# Index(['State', 'Abbrev', 'Code'], dtype='object')

# %%
# To get the count on the number of rows in the dataframe/table we use LEN
len(df)
# Out:
# 51

# %%
# To get the details on both the Number of Rows and Number of Columns we use SHAPE
df.shape
# Out:
# (51, 3)

# %%
# To get the SIZE = ROWS * COLUMNS 
df.size
# Out:
# 153

# %%
# We can configure the minimum number of rows that would be rendered by pandas
pd.options.display.min_rows = 100

# %%
# We can get the info of each column in the dataframe (non-null count, column/data type, etc.)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   51 non-null     object
#  1   Abbrev  51 non-null     object
#  2   Code    51 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
# We can also see just the DTYPES of the columns
df.dtypes
# Out:
# State     object
# Abbrev    object
# Code      object
# dtype: object
