# %% [markdown]
# # replace()

# %%
import pandas as pd

# %%
titanic = pd.read_csv('../../../data/titanic.csv')
ufo = pd.read_csv('../../../data/nuforc_reports.csv 19-47-12-819.csv')

# %%
titanic['cabin']
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304          ?
# 1305          ?
# 1306          ?
# 1307          ?
# 1308          ?
# Name: cabin, Length: 1309, dtype: object

# %% [markdown]
# # We will replace '?' with '???' using the replace() method

# %%
titanic['cabin'].replace('?', '???')
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        ???
# 1305        ???
# 1306        ???
# 1307        ???
# 1308        ???
# Name: cabin, Length: 1309, dtype: object

# %% [markdown]
# # str.replace('target', 'repalce_with') --> This helps to replace the string character

# %%
ufo.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#              date_time     shape     duration  \
# 0  2019-12-12T18:43:00     light    5 seconds
# 1  2019-03-22T18:30:00    circle  3-5 seconds
# 2                  NaN       NaN          NaN
# 3  2019-04-17T02:00:00  teardrop   10 seconds
# 4  2009-03-15T18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %% [markdown]
# ## Using the str.replace() we can replace 'seconds' with 's'

# %%
ufo['duration']
# Out:
# 0          5 seconds
# 1        3-5 seconds
# 2                NaN
# 3         10 seconds
# 4          2 minutes
#             ...
# 88120      3 minutes
# 88121     20 seconds
# 88122     20 seconds
# 88123      2 minutes
# 88124      3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufo['duration'].str.replace('seconds', 's')
# Out:
# 0              5 s
# 1            3-5 s
# 2              NaN
# 3             10 s
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121         20 s
# 88122         20 s
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %% [markdown]
# # str.replace('target1|target2', ' ', regex=True)

# %%
ufo['duration'].str.replace('seconds|minutes', '', regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %% [markdown]
# # Using custom functions in str.replace()

# %%
def abbrev(reo):
    print(reo)
    return 'Hi'

# %%
ufo['duration'].str.replace('seconds|minutes', abbrev, regex=True)
# Out:
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# ...
