# %%
import pandas as pd

countries = pd.read_csv('../data/world-happiness-report-2021.csv')
countries.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# # Sort

# %% [markdown]
# #### sort_values()
# ##### Whichever column we want to use to sort the entire dataframe sort_values(desired_column_to_sort)
# ##### The sorting occurrs in ascending order by default

# %%
countries.sort_values('Healthy life expectancy', ascending=False).head(5)
# Out:
#                  Country name Regional indicator  Ladder score  \
# 31                  Singapore     Southeast Asia         6.377
# 76  Hong Kong S.A.R. of China          East Asia         5.477
# 55                      Japan          East Asia         5.940
# 26                      Spain     Western Europe         6.491
# 2                 Switzerland     Western Europe         7.571
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 31                           0.043         6.460         6.293
# 76                           0.049         5.573         5.380
# 55                           0.040         6.020         5.861
# 26                           0.042         6.574         6.408
# 2                            0.036         7.643         7.500
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 31                 11.488           0.915                   76.953
# 76                 11.000           0.836                   76.820
# ...

# %% [markdown]
# #### inplace = True - Setting this parameter as true makes modification to the original object directly instead of returning a new row

# %%
countries.sort_values("Healthy life expectancy", ascending=False, inplace=True)

# %%
countries
# Out:
#                   Country name  Regional indicator  Ladder score  \
# 31                   Singapore      Southeast Asia         6.377
# 76   Hong Kong S.A.R. of China           East Asia         5.477
# 55                       Japan           East Asia         5.940
# 26                       Spain      Western Europe         6.491
# 2                  Switzerland      Western Europe         7.571
# ..                         ...                 ...           ...
# 129                  Swaziland  Sub-Saharan Africa         4.308
# 84                 Ivory Coast  Sub-Saharan Africa         5.306
# 115                    Nigeria  Sub-Saharan Africa         4.759
# 144                    Lesotho  Sub-Saharan Africa         3.512
# 127                       Chad  Sub-Saharan Africa         4.355
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 31                            0.043         6.460         6.293
# ...
