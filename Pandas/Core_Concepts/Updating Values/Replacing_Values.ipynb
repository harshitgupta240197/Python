# %% [markdown]
# # Replacing Values

# %%
import pandas as pd 

titanic = pd.read_csv('../../data/titanic.csv')
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ##### Replace 'female' with 'f' in the 'sex' columns

# %%
titanic['sex'].replace('female', 'F')
# Out:
# 0          F
# 1       male
# 2          F
# 3       male
# 4          F
#         ...
# 1304       F
# 1305       F
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: object

# %% [markdown]
# ##### Replace both 'Male' and 'Female' with their first letters in the sex column

# %%
titanic['sex'].replace(['female', 'male'], ['F', 'M'], inplace=True)
# Out:
# /var/folders/js/d6m95rq92m76bb_bzchbyb1c0000gn/T/ipykernel_79841/4083433704.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['sex'].replace(['female', 'male'], ['F', 'M'], inplace=True)

# %%
titanic.head()
# Out:
#    pclass  survived                                             name sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton   F
# 1       1         1                   Allison, Master. Hudson Trevor   M
# 2       1         0                     Allison, Miss. Helen Loraine   F
# 3       1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ## If you want to repace something with NONE then you have to wrap NONE In square brackets like a list = [None]

# %% [markdown]
# #### Replace the '?' in the age column with None

# %%
titanic['age'].tail()
# Out:
# 1304    14.5
# 1305       ?
# 1306    26.5
# 1307      27
# 1308      29
# Name: age, dtype: object

# %%
titanic['age'].replace(['?'], [None])
# Out:
# 0           29
# 1       0.9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14.5
# 1305      None
# 1306      26.5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %%
titanic['age'].replace(['?'], [None], inplace=True)
# Out:
# /var/folders/js/d6m95rq92m76bb_bzchbyb1c0000gn/T/ipykernel_79841/3065196104.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].replace(['?'], [None], inplace=True)

# %%
titanic['age'].value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
titanic['age'].tail()
# Out:
# 1304    14.5
# 1305    None
# 1306    26.5
# 1307      27
# 1308      29
# Name: age, dtype: object
